# %%
import yfinance as yf

ticker = yf.Ticker("AAPL")
df = ticker.history(period="5y")
df.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-07-12 00:00:00-04:00  142.518517  142.625741  140.364308  140.851685
# 2021-07-13 00:00:00-04:00  140.393524  143.736931  140.003629  141.962875
# 2021-07-14 00:00:00-04:00  144.360754  145.793640  143.951345  145.384232
# 2021-07-15 00:00:00-04:00  145.471976  146.212782  143.376251  144.731155
# 2021-07-16 00:00:00-04:00  144.711667  145.978833  142.196806  142.693924
#
#                               Volume  Dividends  Stock Splits
# Date
# 2021-07-12 00:00:00-04:00   76299700        0.0           0.0
# 2021-07-13 00:00:00-04:00  100827100        0.0           0.0
# 2021-07-14 00:00:00-04:00  127050800        0.0           0.0
# 2021-07-15 00:00:00-04:00  106820300        0.0           0.0
# 2021-07-16 00:00:00-04:00   93251400        0.0           0.0

# %%
print(df.shape)
df.isnull().sum()
# Out:
# (1255, 7)
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
df['Close'].plot(title="AAPL Closing Price", figsize=(10, 5))
# Out:
# <Axes: title={'center': 'AAPL Closing Price'}, xlabel='Date'>

# %%
df['Close'].describe()
# Out:
# count    1255.000000
# mean      194.631965
# std        45.418469
# min       122.933548
# 25%       157.093887
# 50%       183.438309
# 75%       226.872566
# max       316.220001
# Name: Close, dtype: float64
